# %% [markdown]
# <a href="https://www.kaggle.com/code/aerrashivakumar/wine-quality-prediction-pro-bharat-intern?scriptVersionId=142619942" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/quality-of-red-wine/winequality-red.csv

# %% [markdown]
# **Goal of this project**:
# The main aim of this project is to make a **machine learning model** in order to analyze and predict the quality of wine.

# %% [markdown]
# >># About dataset

# %% [markdown]
# This dataset is related to red variants of the Portuguese "Vinho Verde" wine.
# Here, only physicochemical (inputs) and sensory (the output) variables are taken.
#
# Input variables (based on physicochemical tests):
#
# 1. fixed acidity
# 2. volatile acidity
# 3. citric acid
# 4. residual sugar
# 5. chlorides
# 6. free sulfur dioxide
# 7. total sulfur dioxide
# 8. density
# 9. pH
# 10. sulphates
# 11. alcohol Output variable (based on sensory data) and
# 12. quality (score between 0 and 10)

# %% [markdown]
# >># Importing required libraries:

# %%
#importing libraries that are used in this notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr
from sklearn.model_selection import train_test_split as tts
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier as RFC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix as CM

# %%
#importing dataset
dataset = pd.read_csv('/kaggle/input/quality-of-red-wine/winequality-red.csv')
dataset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
dataset.shape
# Out:
# (1599, 12)

# %% [markdown]
# This describes that the dataset contains 1599 rows and 12 columns.

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
dataset.drop(labels='density', axis=1, inplace=True)

# %% [markdown]
# From above data description we can observe that value of density of wine is almost similar throughout the dataset, because mean, min, 25%, 50%, 75% are all ~0.99.
#
# So I have dropped the density feature as it will not have much significance in predicting quality of wine.

# %% [markdown]
# >># Checking for missing values

# %%
dataset.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# So, there are no missing values in our dataset.

# %% [markdown]
# >># Checking for outliers in our dataset

# %%
#Plotting boxplots to see if there are any outliers in our data (considering data betwen 25th and 75th percentile as non outlier)
fig, ax = plt.subplots(ncols=5, nrows=2, figsize=(15, 5))
ax = ax.flatten()
index = 0
for i in dataset.columns:
  if i != 'quality':
    sns.boxplot(y=i, data=dataset, ax=ax[index])
    index +=1
plt.tight_layout(pad=0.4)
plt.show()

# %% [markdown]
# Here we can see the outliers clearly, BUT we can not remove them because we are trying to predict the quality of wine which means the quality of wine may be good or bad. So we have to consider these also.

# %% [markdown]
# >># Feature Extraction

# %% [markdown]
# Let's try Plotting the bar plots to identify any relation between each independent feature with dependent feature 'Quality'

# %%
fig, ax = plt.subplots(ncols=5, nrows=2, figsize=(15, 5))
ax = ax.flatten()
index=0
for i in dataset.columns:
  if i != 'quality':
    sns.barplot(x='quality', y=i, data=dataset, ax=ax[index])
    index+=1
plt.tight_layout(pad=0.4)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Here we can observe the different qualities of wines w.r.t different input variables.
#
# From the above visualisation we derieve that:
#
# 1. Features fixed acidity and residual sugar might not give any specification to classify/predict the quality.
# 2. Quality increases with
# - decrease in volatile acidity.
# - increase in citric acid.
# - decrease in chlorides.
# - decrease in pH.
# - increase in sulphates.
# - increase in alcohol.
# 3. Free sulfur dioxide alone will not be able to predict the quality.
# 4. Total sulfur dioxide alone will not be able to predict the quality.

# %% [markdown]
# **Plotting correlation heatmap to verify the above statements**

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(dataset.corr(method='pearson'), annot=True, square=True)
plt.show()

print('Correlation of different features of our dataset with quality:')
for i in dataset.columns:
  corr, _ = pearsonr(dataset[i], dataset['quality'])
  print('%s : %.4f' %(i,corr))
# Out:
# Correlation of different features of our dataset with quality:
# fixed acidity : 0.1241
# volatile acidity : -0.3906
# citric acid : 0.2264
# residual sugar : 0.0137
# chlorides : -0.1289
# free sulfur dioxide : -0.0507
# total sulfur dioxide : -0.1851
# pH : -0.0577
# sulphates : 0.2514
# alcohol : 0.4762
# quality : 1.0000

# %%
#for a better view this way can be used
print('Another (more clear) view of correlations among features:\n')
dataset.corr().style.background_gradient(cmap="coolwarm")
# Out:
# Another (more clear) view of correlations among features:
# <style type="text/css">
# #T_90405_row0_col0, #T_90405_row1_col1, #T_90405_row2_col2, #T_90405_row3_col3, #T_90405_row4_col4, #T_90405_row5_col5, #T_90405_row6_col6, #T_90405_row7_col7, #T_90405_row8_col8, #T_90405_row9_col9, #T_90405_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_90405_row0_col1, #T_90405_row4_col10, #T_90405_row8_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_90405_row0_col2 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_90405_row0_col3 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_90405_row0_col4 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_90405_row0_col5, #T_90405_row0_col7, #T_90405_row1_col2, #T_90405_row1_col8, #T_90405_row1_col10, #T_90405_row2_col1, #T_90405_row4_col9, #T_90405_row7_col0, #T_90405_row7_col3, #T_90405_row7_col4, #T_90405_row9_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_90405_row0_col6 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_90405_row0_col8, #T_90405_row3_col7 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_90405_row0_col9, #T_90405_row4_col3 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_90405_row0_col10, #T_90405_row2_col4, #T_90405_row9_col0 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_90405_row1_col0, #T_90405_row3_col4, #T_90405_row5_col3 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_90405_row1_col3, #T_90405_row2_col5 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_90405_row1_col4 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_90405_row1_col5, #T_90405_row5_col9 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_90405_row1_col6 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_90405_row1_col7 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_90405_row1_col9, #T_90405_row6_col9 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_90405_row2_col0 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_90405_row2_col3, #T_90405_row3_col8, #T_90405_row5_col4 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_90405_row2_col6 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_90405_row2_col7, #T_90405_row8_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_90405_row2_col8 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_90405_row2_col9 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_90405_row2_col10 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_90405_row3_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_90405_row3_col1 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_90405_row3_col2, #T_90405_row5_col7 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_90405_row3_col5 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_90405_row3_col6, #T_90405_row6_col0 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_90405_row3_col9 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_90405_row3_col10 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_90405_row4_col0, #T_90405_row8_col10 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_90405_row4_col1 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_90405_row4_col2 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_90405_row4_col5 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_90405_row4_col6 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_90405_row4_col7, #T_90405_row5_col8, #T_90405_row6_col4 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_90405_row4_col8, #T_90405_row8_col4, #T_90405_row10_col2 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_90405_row5_col0 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_90405_row5_col1, #T_90405_row7_col9 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_90405_row5_col2 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_90405_row5_col6 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_90405_row5_col10 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_90405_row6_col1 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_90405_row6_col2 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_90405_row6_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_90405_row6_col5 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_90405_row6_col7 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_90405_row6_col8, #T_90405_row7_col10 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_90405_row6_col10 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_90405_row7_col1 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_90405_row7_col2 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_90405_row7_col5 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_90405_row7_col6 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_90405_row7_col8 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_90405_row8_col0 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_90405_row8_col2 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_90405_row8_col5 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_90405_row8_col6 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_90405_row8_col7 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_90405_row8_col9 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_90405_row9_col1 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_90405_row9_col2 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_90405_row9_col3 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_90405_row9_col4 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_90405_row9_col5 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_90405_row9_col7 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_90405_row9_col8 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_90405_row9_col10 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_90405_row10_col0 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_90405_row10_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_90405_row10_col3 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_90405_row10_col4 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_90405_row10_col5 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_90405_row10_col6 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_90405_row10_col7 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_90405_row10_col8 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_90405_row10_col9 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# </style>
# <table id="T_90405">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90405_level0_col0" class="col_heading level0 col0" >fixed acidity</th>
#       <th id="T_90405_level0_col1" class="col_heading level0 col1" >volatile acidity</th>
#       <th id="T_90405_level0_col2" class="col_heading level0 col2" >citric acid</th>
#       <th id="T_90405_level0_col3" class="col_heading level0 col3" >residual sugar</th>
#       <th id="T_90405_level0_col4" class="col_heading level0 col4" >chlorides</th>
#       <th id="T_90405_level0_col5" class="col_heading level0 col5" >free sulfur dioxide</th>
#       <th id="T_90405_level0_col6" class="col_heading level0 col6" >total sulfur dioxide</th>
#       <th id="T_90405_level0_col7" class="col_heading level0 col7" >pH</th>
#       <th id="T_90405_level0_col8" class="col_heading level0 col8" >sulphates</th>
#       <th id="T_90405_level0_col9" class="col_heading level0 col9" >alcohol</th>
#       <th id="T_90405_level0_col10" class="col_heading level0 col10" >quality</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90405_level0_row0" class="row_heading level0 row0" >fixed acidity</th>
#       <td id="T_90405_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_90405_row0_col1" class="data row0 col1" >-0.256131</td>
#       <td id="T_90405_row0_col2" class="data row0 col2" >0.671703</td>
#       <td id="T_90405_row0_col3" class="data row0 col3" >0.114777</td>
#       <td id="T_90405_row0_col4" class="data row0 col4" >0.093705</td>
#       <td id="T_90405_row0_col5" class="data row0 col5" >-0.153794</td>
#       <td id="T_90405_row0_col6" class="dat

# %% [markdown]
# From the above plots and values we can conclude:
#
# 1. volatile acidity, chlorides and ph are negatively correlated to quality -- hence our statement was right that quality increases with decrease in value of these features; and vice versa for other features.
# 2. free sulfur dioxide and total sulfur dioxide are highly correlated to each other with correlation of 0.67.
# 3. There are many features with correlation < 0.5 to quality, and may be removed from the dataset.
#
# BUT for the same reason as mentioned above in outlier section, that -- we are looking for accuracy to minute levels, not just some approximation — high quality wine may have very rare composition from other average quality wines, hence we need to take every feature in account while predicting quality of wine, so we can not remove or modify outlier values in out dataset.

# %% [markdown]
# >># Machine learning

# %% [markdown]
# Now implementing classification algorithms based machine learning models and selecting the best out of them based on some score.

# %% [markdown]
# **First let's prepare our dataset for Machine Learning**

# %%
dataset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide    pH  sulphates  alcohol  \
# 0                 11.0                  34.0  3.51       0.56      9.4
# 1                 25.0                  67.0  3.20       0.68      9.8
# 2                 15.0                  54.0  3.26       0.65      9.8
# 3                 17.0                  60.0  3.16       0.58      9.8
# 4                 11.0                  34.0  3.51       0.56      9.4
#
#    quality
# 0        5
# 1        5
# 2        5
# 3        6
# 4        5

# %% [markdown]
# Dividing quality of wine in two buckets, ie. Good wine and Bad wine, and on the basis of this we will give our final result

# %%
bins = (2, 6.5, 8)
group_names = ['bad', 'good']
dataset['quality'] = pd.cut(dataset['quality'], bins = bins, labels = group_names)
dataset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide    pH  sulphates  alcohol quality
# 0                 11.0                  34.0  3.51       0.56      9.4     bad
# 1                 25.0                  67.0  3.20       0.68      9.8     bad
# 2                 15.0                  54.0  3.26       0.65      9.8     bad
# 3                 17.0                  60.0  3.16       0.58      9.8     bad
# 4                 11.0                  34.0  3.51       0.56      9.4     bad

# %% [markdown]
# From the above code have divided the quality of wine in two buckets:
#
# - Bad wine : range 2 - 6.5
# - Good wine : range 6.5 - 8
# This can be changed as per the requiremnt of our client.
#
# Now we will map the values of bad and good to 0 and 1 respectively, as machine learning models can perform calculation only on numerical data.

# %%
dataset['quality'] = dataset['quality'].map({'bad' : 0, 'good' : 1})
dataset.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide    pH  sulphates  alcohol quality
# 0                 11.0                  34.0  3.51       0.56      9.4       0
# 1                 25.0                  67.0  3.20       0.68      9.8       0
# 2                 15.0                  54.0  3.26       0.65      9.8       0
# 3                 17.0                  60.0  3.16       0.58      9.8       0
# 4                 11.0                  34.0  3.51       0.56      9.4       0
# 5                 13.0                  40.0  3.51       0.56      9.4       0
# 6                 15.0                  59.0  3.30       0.46      9.4       0
# 7                 15.0                  21.0  3.39       0.47     10.0       1
# 8                  9.0                  18.0  3.36       0.57      9.5       1
# 9                 17.0                 102.0  3.35       0.80     10.5       0

# %% [markdown]
# Let's count and visualise the total number of different wine samples

# %%
print(dataset['quality'].value_counts())
fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(15, 5))
ax = ax.flatten()
print('\nVisualisation of accuracies of differnt classification models')
dataset['quality'].value_counts().plot(x=0, y=1, kind='pie', figsize=(15,5), ax=ax[0])
sns.countplot(dataset['quality'], ax=ax[1])
plt.show()
# Out:
# quality
# 0    1382
# 1     217
# Name: count, dtype: int64
#
# Visualisation of accuracies of differnt classification models

# %% [markdown]
# Creating set of independent and dependent features

# %%
X = dataset.iloc[:, :-1]
Y = (dataset.iloc[:, 10])

# %% [markdown]
# Creating traing and test set

# %%
X_train, X_test, Y_train, Y_test = tts(X, Y, test_size=0.20, random_state=0)

# %% [markdown]
# Feature scaling, but not scaling dependent variable as it has catagorical data

# %%
from sklearn.preprocessing import StandardScaler as ss
SS = ss()
X_train = SS.fit_transform(X_train)
X_test = SS.transform(X_test)

# %% [markdown]
# **Now implementing machine learning models**

# %% [markdown]
# Logistic Regression Classification

# %%
logisticRegression = LogisticRegression(solver='lbfgs', random_state=0)
logisticRegression.fit(X_train,Y_train)
Y_pred_logisticRegression = logisticRegression.predict(X_test)
Y_compare_logisticRegression = pd.DataFrame({'Actual' : Y_test, 'Predicted' : Y_pred_logisticRegression})
print(Y_compare_logisticRegression.head())
print('\nConfussion matrix:')
print(CM(Y_test, Y_pred_logisticRegression))
# Out:
#      Actual  Predicted
# 1109      0          0
# 1032      0          0
# 1002      1          1
# 487       0          0
# 979       0          0
#
# Confussion matrix:
# [[276  14]
#  [ 18  12]]

# %% [markdown]
# K-Nearest Neighbour Classification

# %%
knn = KNN(n_neighbors=2, metric='minkowski', p=2,)
knn.fit(X_train, Y_train)
Y_pred_knn = knn.predict(X_test)
Y_compare_knn = pd.DataFrame({'Actual' : Y_test, 'Predicted' : Y_pred_knn})
print(Y_compare_knn.head())
print('\nConfussion matrix:')
print(CM(Y_test, Y_pred_knn))
# Out:
#      Actual  Predicted
# 1109      0          0
# 1032      0          0
# 1002      1          1
# 487       0          0
# 979       0          0
#
# Confussion matrix:
# [[280  10]
#  [ 14  16]]

# %% [markdown]
# Support Vector Classification(SVC)

# %%
svc = SVC(kernel='rbf', gamma='scale', random_state=0)
svc.fit(X_train, Y_train)
Y_pred_svc = svc.predict(X_test)
Y_compare_svc = pd.DataFrame({'Actual' : Y_test, 'Predicted' : Y_pred_svc})
print(Y_compare_svc.head())
print('\nConfussion matrix:')
print(CM(Y_test, Y_pred_svc))
# Out:
#      Actual  Predicted
# 1109      0          0
# 1032      0          0
# 1002      1          1
# 487       0          0
# 979       0          0
#
# Confussion matrix:
# [[285   5]
#  [ 21   9]]

# %% [markdown]
# Naive Bayes Calssification

# %%
nb = GaussianNB()
nb.fit(X_train, Y_train)
Y_pred_nb = nb.predict(X_test)
Y_compare_nb = pd.DataFrame({'Actual' : Y_test, 'Predicted' : Y_pred_nb})
print(Y_compare_nb.head())
print('\nConfussion matrix:')
print(CM(Y_test, Y_pred_nb))
# Out:
#      Actual  Predicted
# 1109      0          0
# 1032      0          0
# 1002      1          1
# 487       0          0
# 979       0          1
#
# Confussion matrix:
# [[241  49]
#  [  7  23]]

# %% [markdown]
# Random Forrest Classification

# %%
rfc = RFC(n_estimators=25, criterion='gini', random_state=0,)
rfc.fit(X_train, Y_train)
Y_pred_rfc = rfc.predict(X_test)
Y_compare_rfc = pd.DataFrame({'Actual' : Y_test, 'Predicted' : Y_pred_rfc})
print(Y_compare_rfc.head())
print('\nConfussion matrix:')
print(CM(Y_test, Y_pred_rfc))
# Out:
#      Actual  Predicted
# 1109      0          0
# 1032      0          0
# 1002      1          1
# 487       0          0
# 979       0          0
#
# Confussion matrix:
# [[283   7]
#  [  9  21]]

# %% [markdown]
# Checking the accuracy of different classification models:

# %%
#K-fold cross validation
modelNames = ['Logistic Regression', 'K-Nearest Neighbour', 'Support Vector', 'Naive Bayes', 'Random Forrest']
modelClassifiers = [logisticRegression, knn, svc, nb, rfc]
models = pd.DataFrame({'modelNames' : modelNames, 'modelClassifiers' : modelClassifiers})
counter=0
score=[]
for i in models['modelClassifiers']:
  accuracy = cross_val_score(i, X_train, Y_train, scoring='accuracy', cv=10)
  print('Accuracy of %s Classification model is %.2f' %(models.iloc[counter,0],accuracy.mean()))
  score.append(accuracy.mean())
  counter+=1
# Out:
# Accuracy of Logistic Regression Classification model is 0.87
# Accuracy of K-Nearest Neighbour Classification model is 0.87
# Accuracy of Support Vector Classification model is 0.88
# Accuracy of Naive Bayes Classification model is 0.83
# Accuracy of Random Forrest Classification model is 0.90

# %%
pd.DataFrame({'Model Name' : modelNames,'Score' : score}).sort_values(by='Score', ascending=True).plot(x=0, y=1, kind='bar', figsize=(15,5), title='Comparison of accuracies of differnt classification models')
plt.show()

# %% [markdown]
# From the above scores and visualiations we can conclude that Random Forrest Classification model gives the best score and we can use it to predict the quality of wine for this particular problem.
#
# However other models like Logisgic Regression, KNN and SVC also have comparable score to Random Forrest and may also be used to predict quality of wine.

# %% [markdown]
# # Summary of this project

# %% [markdown]
# - Firstly, we have interpreted about the dataset and what exactly our aim is.
# - Then we have imported the required libraries.
# - Secondly, we have cleaned the data by dropping the unnessary columns or rows and checked for the presence of null values.
# - We have chosen not to remove outliers and extract the more relavant features form out dataset - as we were looking for accuracy to minute levels, not just some approximation (high quality wine may have very rare composition from other average quality wines)
# - Since we know that Random Forest gives us more accurate rate of finding the quality of wine.
# - That is, Random Forrest Classification model gave the best accuracy and can be considered as a good model for predictiong the quality of wine for this problem.
# - However other models like Logisgic Regression, KNN and SVC also have comparable score to Random Forrest and may also be used to predict quality of wine.
# - Naive Bayes model gave the least accuracy, which can be considered bad model to predict the quality of fine.
# - We might(will) get different results if we remove outliers and consider feature extraction.
#
#
# On concluding this project of predicting the quality of wine which is more than 80% accurate.
# I request the viewers to check for the errors in this projec(if any) as it helps me to modify and upgrade more.
# I am also want to mention that no data is perfect in this world.
# Thank you!
